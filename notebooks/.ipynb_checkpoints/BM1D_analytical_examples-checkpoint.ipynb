# %% [markdown]
# # Box Model Examples

# %% [markdown]
# ## Comparison with analytical solutions
# In this example, we initialize the model and run some tests alongside analytical solutions from Scott (1968) and Feingold et al. (1988). In order to use the model, we first need to import the spectral_1d class from the spectral_model module. We'll also set up some parameters for the initial mass grid.

# %%
from binmod1d.spectral_model import spectral_1d 
sbin = 4 # Bin resolution scaling
bin_res = 14 # bin scaling factor
bins = sbin*bin_res # Total number of bins
x0 = 0.05 # first bin left-hand edge mass

# %% [markdown]
# Now we can test the model against known analytical solutions in a box model setup.

# %% [markdown]
# ### Scott (1968) Solutions
#
# We'll start with the series solutions provided by Scott (1968).
#
# #### The Golovin Solution: $K(x,y) = \overline{E} (x+y)$
# By default, the spectral bin model is set up to replicate the Scott (1968) solutions with the Golovin (summation) kernel and $\mu=3$ . Therefore, we can simply initialize a spectral_1d model as follows:

# %%
s4_golovin = spectral_1d(sbin=sbin,bins=bins,x0=x0,tmax=60.*12.,dist_var='mass',kernel='Golovin',gam_norm=True)

# %% [markdown]
# We can plot the initial distribution using the plot_init() method. This is a good way to make sure you have enough bins to cover the range of particle mass/sizes that will be needed appropriately resolve the collision-coalescence/breakup process for a given initial distribution and parameters.

# %%
s4_golovin.plot_init()
# Out:
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# Now we can run the model as a box model by using the spectral_1d run method

# %%
s4_golovin.run()
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.08 min

# %% [markdown]
# Now we can plot the results for the last time period by using the plot_dists method and compare with W. D. Scott's analytical solution. The $t_{ind}$ parameter in the plot_dists method can be used to select the time index you would like to plot (following python convention, $t_{ind}=-1$ takes the last available time). To enable the plotting of the analytical solution as a red dotted line, use the scott_solution input.

# %%
s4_golovin.plot_dists(tind=-1,scott_solution=True)
# Out:
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# ### The Product Kernel Solution: $K(x,y) = \overline{E}\, x\, y$
# Now, we'll test the product kernel solution. Keep in mind that the product kernel does not strictly conserve mass once gellation occurs (see Alfonso et al. 2008, for a discussion on this: www.atmos-chem-phys.net/8/969/2008/). Actually, according to Alfonso et al. 2008, the Golovin kernel also does not conserve mass after a certain amount of time but this unphysical behavior is much more pronounced with the fat-tailed distribution resulting from using the product kernel. Again, let's do $\mu=3$ and $t_{\max}=400$. Also, let's modify $x_{0}$ so that the extended tail of the product kernel solution is better resolved.

# %%
s4_product = spectral_1d(kernel='Product',sbin=sbin,bins=bins,gam_norm=True,tmax=60.*10.,x0=x0,dist_var='mass')
s4_product.run()
s4_product.plot_dists(tind=-1,scott_solution=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.06 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# ### The Constant Kernel Solution: $K(x,y)=\overline{E}$
# Finally, we'll do the constant kernel.

# %%
s4_constant = spectral_1d(kernel='Constant',sbin=sbin,bins=bins,gam_norm=True,tmax=60.*20.,x0=x0,dist_var='mass')
s4_constant.run()
s4_constant.plot_dists(tind=-1,scott_solution=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.07 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# ## Feingold et al. (1988) Solutions

# %% [markdown]
# Next we'll test the Collisional Breakup and Coalescence/Breakup steady-state analytical solutions in Feingold et al. (1988). We'll initialize a spectral_1d object as before but use the Eb parameter option to turn on collisional breakup. Also, we'll need to change the $x_{0}$ parameter to better resolve the low end of the particle size distribution. Finally, we'll need to specify a fragment distribution using the `frag_dist='exp_mass'` input parameter. This fragment distribution is given by
#
# $$
# P(m|x,y) = \Lambda_{f}^{2} (x+y) \exp\left( - \Lambda_{f} m \right),
# $$
#
# where $\Lambda_{f}$ governs the average number of fragments generated for each breakup event.

# %% [markdown]
# ### Breakup Solution

# %%
s6_breakup = spectral_1d(sbin=6,bins=120,kernel='Constant',frag_dist='exp_mass',dist_var='mass',tmax=1800,gam_norm=True,mu0=0.,Eb=0.1,Es=0.,x0=0.0001)
s6_breakup.run()
s6_breakup.plot_dists(tind=-1,feingold_solution=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.48 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# ### Steady-state Collision-Coalescence/Breakup solution

# %% [markdown]
# Now we'll do both collision_coalescence and breakup and compare the solution at $t_{\max}=6000$ sec to the steady-state solution from Feingold et al. (1988).

# %%
s4_BC = spectral_1d(sbin=4,bins=80,kernel='Constant',frag_dist='exp_mass',dist_var='mass',gam_norm=True,mu0=0.,tmax=6000,Eb=1.0,Es=0.8,x0=0.0001)
s4_BC.run()
s4_BC.plot_dists(tind=-1,feingold_solution=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.66 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='dN/dlog(m)'>,
#         <Axes: xlabel='log(m) [log(g)]', ylabel='dM/dlog(m)'>],
#        dtype=object))

# %% [markdown]
# Notice that the Feingold solutions don't exactly match the model results regardless of resolution/bins. This is because, as explained in Feingold et al. (1988), the analytical solutions use a fragment distribution that doesn't exactly conserve collision-by-collision total mass (but does conserve overall mass for the entire distribution). Therefore the validity of the analytical solution is predicated on the chosen $\Lambda_{f}$ parameter (see the fragments function in the habits.py module). The bin model on the other hand does, by its nature, preserve collision-by-collision total mass.

# %% [markdown]
# ### 2 Moment versus 1 moment tests

# %% [markdown]
# Now we'll test the 1 moment versus 2 moment calculations for the analytic tests. We'll run the Golovin case out to 1 hour for both sets of calculations. To speed things up a bit, we'll use a lower $s_{\mathrm{bin}}$ value.

# %%
s3_golovin_1mom = spectral_1d(sbin=3,bins=90,kernel='Golovin',dist_var='mass',x0=0.001,tmax=3600,gam_norm=True,moments=1)
s3_golovin_2mom = spectral_1d(sbin=3,bins=90,kernel='Golovin',dist_var='mass',x0=0.001,tmax=3600,gam_norm=True,moments=2)
s3_golovin_1mom.run()
s3_golovin_2mom.run()
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Model Complete! Time Elapsed = 0.23 min
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.29 min

# %% [markdown]
# Now let's plot both solutions at 1 hour. We can pass in the ```linestyle``` and ```color``` pyplot parameters in ```plot_dists()``` to overlay the plots on each other. We'll also use the ```normbin``` parameter to normalize each distribution to unity so that we can better see the change in shape between the initial and final distributions.

# %%
fig, ax = s3_golovin_1mom.plot_dists(normbin=True,scott_solution=True,linestyle='-',color='k')
s3_golovin_2mom.plot_dists(normbin=True,scott_solution=True,ax=ax,linestyle='--',color='k')

# %% [markdown]
# The 1 moment calculations overall are pretty similar to the 2 moment calculations. There is a bit of overestimation of the mass distribution of the 1 moment solution at larger masses. This is due to the more diffusive nature of the 1 moment solution compared to the more accurate 2 moment solution.

# %% [markdown]
# ## Long Kernel

# %% [markdown]
# Now let's try to test convergence of BinMod1D using the Long kernel. Here, we'll use the hydrodynamic kernel but use a non-constant collision efficiency given by (cf. Long 1974; Simmel et al. 2000):
#
# $E_{\mathrm{col}}(x,y)\, [\mathrm{mm}^{3}/\mathrm{s}] = \max\left[112.5\, D_{y}^2 \left(1 - \frac{0.006}{D_{x}}\right),0.001\right]$
#
# We'll set up the initial distribution explicitly by using the ```init_method='analytical'``` option where we'll use the exponential mass distribution(cf. Simmel et al. 2000; Wang et al. 2008)
# $$
# n_{0}(m) = \frac{N_{t,0}}{\overline{m}_{0}}\exp(-m/\overline{m}_{0}).
# $$
# We'll also use $N_{t,0}$ and $M_{t,0}$ values that are consistent with the continental cloud droplet values from Long (1974).

# %%
# For more information, see Simmel et al. (2000)
import numpy as np
output_freq = 10
bin1 = 45 # number of bins for sbin=1
sbin = 2
bins = bin1*sbin # Keeps xmin and xmax consistent for each resolution.   
mu0 = 0
moms = 2
tmax = 2400. # s 
dt = 1.0 # s
r0 = 9.3e-3 # mm
m0 = 0.001*((4./3.)*np.pi*(r0)**3) # g
Mt0 = 1.0 # g/m^3
x0 = 1e-12 # g
Nt0 = Mt0/m0 # Put in #/m^3 for model input
mbar0 = Mt0/Nt0
# We'll set up an exponential distribution w.r.t. mass directly using the 'init_method' input parameter.
# Keep in mind that nD_func needs to have units of 1/m^3 1/mm!
func_nD = lambda x: (Nt0/mbar0)*np.exp(-x/mbar0)

s2_long_2mom = spectral_1d(sbin=sbin,bins=bins,tmax=tmax,dt=dt,x0=x0,kernel='Long',Ecol=1.0,Es=0.5,dist_var='mass',init_method='analytical',func_nD=func_nD,moments=moms)
s2_long_2mom.run()
s2_long_2mom.plot_dists(-1,x_axis='size',normbin=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# Model Complete! Time Elapsed = 0.19 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='d$P_{N}$/dlog(D)'>,
#         <Axes: xlabel='log(D) [log(mm)]', ylabel='d$P_{M}$/dlog(D)'>],
#        dtype=object))

# %% [markdown]
# Notice that we plot here with the ```normbin``` parameter which normalizes the number distribution function by $N_{t}$ and the mass distribution function by $M_{t}$ (this helps because cloud droplet concentrations are much higher than for rain). Now let's see what the corresponding 1 moment run looks like.

# %%
s2_long_1mom = spectral_1d(sbin=sbin,bins=bins,tmax=tmax,dt=dt,x0=x0,kernel='Long',Ecol=1.0,Es=0.5,dist_var='mass',init_method='analytical',func_nD=func_nD,moments=1)
s2_long_1mom.run()
s2_long_1mom.plot_dists(-1,x_axis='size',normbin=True)
# Out:
# Running 1D spectral bin model:   0%|                                                                          …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Model Complete! Time Elapsed = 0.09 min
# (<Figure size 800x1000 with 2 Axes>,
#  array([<Axes: ylabel='d$P_{N}$/dlog(D)'>,
#         <Axes: xlabel='log(D) [log(mm)]', ylabel='d$P_{M}$/dlog(D)'>],
#        dtype=object))

# %% [markdown]
# Notice that even with $s_{\mathrm{bin}}=4$, the single moment run is noticeably more diffusive for sizes that are greater than or around 1 mm.
